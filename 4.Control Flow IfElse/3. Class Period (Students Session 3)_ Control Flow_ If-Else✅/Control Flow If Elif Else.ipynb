# %% [markdown]
# ## Control Flow : if, elif, else

# %% [markdown]
# ## If Else

# %%
# untuk mengecek kondisi umur >18 serta <18
age = float(input("Masukkan umur Anda: "))
# print(type(age))
if age >= 18:
    print("Anda sudah dewasa.")
else: # <18
    print("Anda masih di bawah umur.")
# Out:
# Masukkan umur Anda: 11.5
# Anda masih di bawah umur.

# %%
# untuk mengecek kondisi umur >18 serta <18
age = int(input("Masukkan umur Anda: "))

if age >= 18:
    print("Anda sudah dewasa.")
elif age <= 18:
    print("Anda masih di bawah umur.")
# Out:
# Masukkan umur Anda: 10
# Anda masih di bawah umur.

# %% [markdown]
# ## Nested Condition

# %%
# ingin mengecek bilangan ganjil genap dengan tambahan bukan bilangan positif
x = float(input("Masukkan angka: "))
if x > 0: # kondisi lebih dari 0
    if x % 2 == 0: # kondisi positif genap
        print("Positif Genap")
    else: # kondisi positif ganjil
        print("Positif Ganjil")
else:
    print("Bukan bilangan positif")
# Out:
# Masukkan angka: -3
# Bukan bilangan positif

# %%
-6 % 2 # negatif genap
# Out:
# 0

# %%
# ingin mengecek bilangan ganjil genap dengan tambahan bukan bilangan positif
# bukan bilangan positif berarti negatif atau netral
x = float(input("Masukkan angka: "))
if x > 0: # kondisi lebih dari 0 / positif
    if x % 2 == 0: # kondisi positif genap
        print("Positif Genap")
    else: # kondisi positif ganjil
        print("Positif Ganjil")
elif x < 0: # kondisi bilangan negatif
    if x % 2 == 0: # kondisi negatif genap
        print("Negatif Genap")
    else: # kondisi negatif ganjil
        print("Negatif Ganjil")
else : # kondisi bilangan netral
  print("bilangan 0 atau netral")
# Out:
# Masukkan angka: -3
# Negatif Ganjil

# %% [markdown]
# ## Contoh 1 – Age Classifier

# %%
age = int(input("Masukkan umur Anda: "))

# kondisi age -> < 13, age < 17, age < 60, selain itu


if age < 13: # < dibawah 13
    print("Kategori: Anak-anak")
elif age < 18: # kondisinya diantara 13 hingga 18
    print("Kategori: Remaja")
elif age < 60: # kondisinya diantara 18 hingga 60
    print("Kategori: Dewasa")
else:
    print("Kategori: Lansia")
# Out:
# Masukkan umur Anda: 70
# Kategori: Lansia

# %%
# Handling Input yg gak sesuai
while True:
    try:
        # Meminta input umur
        age = float(input("Masukkan umur Anda: "))

        # Jika angka valid, tentukan kategori umur
        if age < 0:
            print("Umur tidak boleh negatif. Coba lagi!")
            continue

        if age < 13:
            print("Kategori: Anak-anak")
        elif age < 18:
            print("Kategori: Remaja")
        elif age < 60:
            print("Kategori: Dewasa")
        else:
            print("Kategori: Lansia")

        # Setelah berhasil cetak kategori, keluar dari loop
        break

    except ValueError:
        print("Input tidak valid! Masukkan angka saja.")
# Out:
# Masukkan umur Anda: -20
# Umur tidak boleh negatif. Coba lagi!
# Masukkan umur Anda: 70
# Kategori: Lansia

# %% [markdown]
# ## Contoh 2 – Grade Classifier

# %%
score = float(input("Masukkan nilai ujian: "))

if score >= 90:
    print("Grade: A")
elif score >= 75:
    print("Grade: B")
elif score >= 60:
    print("Grade: C")
elif score >= 45:
    print("Grade: D")
else:
    print("Grade: E")
# Out:
# Masukkan nilai ujian: 89.99999
# Grade: B

# %% [markdown]
# ## Hands-on: Age Classifier (Nested + Logical Operator)

# %%
# Age Classifier dengan Nested Conditions
age = int(input("Masukkan umur Anda: "))
is_student = input("Apakah Anda seorang pelajar? (ya/tidak): ").lower()

if age >= 18:
    if is_student == "ya":
        print("Kategori: Pelajar Dewasa")
    else:
        print("Kategori: Dewasa Bekerja")
else:
    if is_student == "ya":
        print("Kategori: Pelajar di Bawah Umur")
    else:
        print("Kategori: Bukan Pelajar di Bawah Umur")
# Out:
# Masukkan umur Anda: 20
# Apakah Anda seorang pelajar? (ya/tidak): tidak
# Kategori: Dewasa Bekerja

# %% [markdown]
# ### Versi lebih ringkas dengan logical operator:

# %%
age = int(input("Masukkan umur Anda: "))
is_student = input("Apakah Anda seorang pelajar? (ya/tidak): ").lower()

if age >= 18 and is_student == "ya": # kondisi pelajar dewasa
    print("Kategori: Pelajar Dewasa")
elif age >= 18 and is_student != "ya": # kondisi dewasa bekerja
    print("Kategori: Dewasa Bekerja")
elif age < 18 and is_student == "ya": # kondisi pelajar dibawah umur
    print("Kategori: Pelajar di Bawah Umur")
else: # kondisi bukan pelajar di bawah umur
    print("Kategori: Bukan Pelajar di Bawah Umur")
# Out:
# Masukkan umur Anda: 30
# Apakah Anda seorang pelajar? (ya/tidak): tidaK
# Kategori: Dewasa Bekerja

# %%
age = int(input("Masukkan umur Anda: "))
is_student = input("Apakah Anda seorang pelajar? (ya/tidak): ").lower()

if age >= 18 and is_student == "ya":
    print("Kategori: Pelajar Dewasa")
elif age >= 18 and is_student != "ya":
    print("Kategori: Dewasa Bekerja")
elif age < 18 and is_student == "ya":
    print("Kategori: Pelajar di Bawah Umur")
else:
    print("Kategori: Bukan Pelajar di Bawah Umur")

# %%
age = int(input("Masukkan umur Anda: "))
is_student = input("Apakah Anda seorang pelajar? (ya/tidak): ").lower()
gender = input("Gendermu apa ? (pria/wanita): ").lower()

if (age >= 18 and is_student == "ya") or gender == "pria":
    print("Kategori: Prioritas Pelajar Dewasa atau Semua Pria")
elif (age < 18 and is_student == "ya") or gender == "wanita":
    print("Kategori: Pelajar Muda atau Semua Wanita")
elif age >= 18 or is_student == "ya":
    print("Kategori: Dewasa atau Pelajar (umum)")
else:
    print("Kategori: Lainnya")
# Out:
# Masukkan umur Anda: 20
# Apakah Anda seorang pelajar? (ya/tidak): tidak
# Gendermu apa ? (pria/wanita): pria
# Kategori: Prioritas Pelajar Dewasa atau Semua Pria

# %% [markdown]
# ## 3. Hands-on: Grade Classifier (Nested + Logical Operator)

# %%
# Grade Classifier dengan Nested Conditions
score = int(input("Masukkan nilai ujian Anda: "))

if score >= 90:
    print("Grade: A")
    if score >= 95:
        print("Predikat: Istimewa")
    else:
        print("Predikat: Sangat Baik")
elif score >= 75:
    print("Grade: B")
    if score >= 85:
        print("Predikat: Baik Sekali")
    else:
        print("Predikat: Baik")
elif score >= 60:
    print("Grade: C")
    if score >= 65:
        print("Predikat: Cukup Memuaskan")
    else:
        print("Predikat: Cukup")
elif score >= 45:
    print("Grade: D")
    print("Predikat: Kurang")
else:
    print("Grade: E")
    print("Predikat: Sangat Kurang")

# %% [markdown]
# ### Versi lebih ringkas dengan logical operator:

# %%
score = int(input("Masukkan nilai ujian Anda: "))

if score >= 90:
    print("Grade: A", "| Predikat:", "Istimewa" if score >= 95 else "Sangat Baik")
elif 75 <= score < 90:
    print("Grade: B", "| Predikat:", "Baik Sekali" if score >= 85 else "Baik")
elif 60 <= score < 75:
    print("Grade: C", "| Predikat:", "Cukup Memuaskan" if score >= 65 else "Cukup")
elif 45 <= score < 60:
    print("Grade: D | Predikat: Kurang")
else:
    print("Grade: E | Predikat: Sangat Kurang")
# Out:
# Masukkan nilai ujian Anda: 20
# Grade: E | Predikat: Sangat Kurang

# %%
age = int(input("Masukkan umur Anda: "))
is_student = input("Apakah Anda seorang pelajar? (ya/tidak): ").lower()
gender = input("Gendermu apa ? (pria/wanita): ").lower()

# age, student, gender -> kenali batasannya dan kombinasikan

if age >= 18 and is_student == "ya":
    if gender == "pria":
        print("Kategori: Pelajar Dewasa (Pria)")
    else:
        print("Kategori: Pelajar Dewasa (Wanita)")
elif age >= 18 and is_student != "ya":
    if gender == "pria":
        print("Kategori: Dewasa Bekerja (Pria)")
    else:
        print("Kategori: Dewasa Bekerja (Wanita)")
elif age < 18 and is_student == "ya":
    if gender == "pria":
        print("Kategori: Pelajar di Bawah Umur (Pria)")
    else:
        print("Kategori: Pelajar di Bawah Umur (Wanita)")
else:
    if gender == "pria":
        print("Kategori: Bukan Pelajar di Bawah Umur (Pria)")
    else:
        print("Kategori: Bukan Pelajar di Bawah Umur (Wanita)")
